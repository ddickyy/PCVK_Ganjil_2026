# %% [markdown]
# <a href="https://colab.research.google.com/github/ddickyy/PCVK_Ganjil_2026/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # STEP 1

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# # Penjelasan singkat
#
# numpy Mengolah angka dan array/matriks
#
# pandas Mengolah data tabel
#
# cv2 Pengolahan citra/gambar menggunakan OpenCV
#
# cv2_imshow Menampilkan gambar di Google Colab
#
# skimage.io Membaca/menulis gambar
#
# skimage.transform Transformasi gambar
#
# PIL.Image Membuka dan memanipulasi gambar
#
# matplotlib.pyplot Menampilkan gambar, grafik, dan visualisasi

# %% [markdown]
# # STEP 2
# Baca image dari URL

# %%
# Membuat list menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
      ]
# baca dan tampilkan gambar
# loop pada tiap url, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)   # baca image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) # resize image hhalf size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB) # convert image to RGB
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# # STEP 3
# Melihat ukuran File image

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("Resolusi image: tinggi x lebar = ", tinggi, "x", lebar)
cv2_imshow(image_2)
# Out:
# Resolusi image: tinggi x lebar =  286 x 400
# <PIL.Image.Image image mode=RGB size=400x286>

# %% [markdown]
# # STEP 4
# Mengakses piksel dengan garis diagonal menyilang

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis horizontal di tengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2,image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# # PERTANYAAN PRAKTIKUM D2
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# Karena Colab berjalan di cloud tanpa harus menginstall python
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke
# delapan? Apakah semua library tersebut harus digunakan dalam praktikum
# sesi ini?
#
# *   NumPy: Untuk hitung-hitungan angka dan struktur data gambar (matriks).
# * Pandas: Untuk mengolah data berbentuk tabel.
# * OpenCV (cv2): Library utama untuk manipulasi gambar (seperti mengubah warna atau ukuran).
# * Matplotlib/PIL: Untuk menampilkan dan memvisualisasikan gambar. Tidak semua perlu digunakan, tergantung kebutuhan
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# `image = cv.resize(image, (0,0), fx=0.5, fy=0.5)`
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak
# dilakukan? gambar diperkecil menjadi setengah (50%) dari ukuran aslinya, baik secara horizontal maupun vertikal. Jika tidak dilakukan, ukuran gamabr akan ditampilkan sama dengan aslinya
# 4. Perhatikan potongan kode progam berikut :
# Membuat garis horizontal di tengah image
# for y in range (lebar):
# `  image_3[int((tinggi)/2),y] = [255,255,255]`
# Apakah kegunaan kode `[255,255,255]` ? Jelaskan!
# Kode itu digunakan untuk memilih warna dari garis. kode `[255,255,255]`ini adalah kombinasi dari RGB yang menghasilkan warna putih
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
# * Piksel: Adalah titik-titik kecil warna yang membentuk gambar.
# * Resolusi Tinggi: Berarti ada sangat banyak piksel dalam satu gambar, sehingga gambar terlihat tajam dan detail.
# * Resolusi Rendah: Pikselnya sedikit, sehingga gambar terlihat pecah atau 'kotak-kotak' (pixelated) saat diperbesar.

# %% [markdown]
# # TUGAS PRAKTIKUM D2
# 1. Lakukan langkah-langkah praktikum seperti diatas
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran
# 3. Buat garis horisontal berwarna putih dibagian tengah gambar dengan
# panjang tertentu
# 4. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat
# dalam gambar

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis vertikal
for x in range (tinggi):
  image_3[x,int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis diagonal menyilang
cv.line(image_3, (0, 0), (lebar - 1, tinggi - 1), (255, 255, 255), 1)
cv.line(image_3, (0, tinggi - 1), (lebar - 1, 0), (255, 255, 255), 1)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

cv.line(image_3, (100, int((tinggi)/2)), (250, int((tinggi)/2)), (255, 255, 255), 1)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

image_3 [50:180, 80:200] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2b3d6dc0-002d-4b1e-a072-c6c24c8b445e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2b3d6dc0-002d-4b1e-a072-c6c24c8b445e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# menampilkan gambar
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/WhatsApp Image 2026-08-31 at 11.17.29 AM.jpeg") #sesuai nama file
cv2_imshow(img)

print("Resolusi gambar:", img.shape[1], "x", img.shape[0])
#
# Out:
# <PIL.Image.Image image mode=RGB size=2090x1313>
# Resolusi gambar: 2090 x 1313

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

#format BGR
img = cv2.imread("/content/WhatsApp Image 2026-08-31 at 11.17.29 AM.jpeg")

#Format RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

final_frame = cv2.hconcat((img_rgb, img))
plt.imshow(final_frame)

# %%
#Gray scale
img_gray = cv2.imread("/content/WhatsApp Image 2026-08-31 at 11.17.29 AM.jpeg", cv2.IMREAD_GRAYSCALE)

#tanpa cmap
plt.subplot(1,2,1)
plt.imshow(img_gray)
plt.title("Tanpa cmap")

#dengan cmap
plt.subplot(1,2,2)
plt.imshow(img_gray, cmap="gray")
plt.title("Dengan cmap")

plt.show()

# %%
#resizing
img = cv2.imread("/content/WhatsApp Image 2026-08-31 at 11.17.29 AM.jpeg")
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #konversi BGR ke RGB
imgRGBsmall = cv2.resize(imgRGB,(400,250))
plt.imshow(imgRGBsmall)

# %%
# flipping
imgBalik = cv2.flip(imgRGBsmall, 1)
plt.imshow(imgBalik)

# %%
imgBalik = cv2.flip(imgRGBsmall, 1)

# canvas lebih besar
fig = plt.figure(figsize=(10,10))
ax=fig.add_subplot(111)
ax.imshow(imgBalik)

# %% [markdown]
# # Geomteri 2D

# %%
black_img = np.zeros(shape=[512,512,3], dtype=np.int16)
plt.imshow(black_img)

# %%
# koordinat pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,25),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],
                    [200,200],
                    [400,300],
                    [200,400]], dtype=np.int32)

# %%
pts = vertices.reshape((-1,1,2))
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)
